# %% [markdown]
# <a href="https://colab.research.google.com/github/raviraj2833/python/blob/main/Pandas_lib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas library:
# useful for Data processing & Analysis
#
# Pandas Data frame:
# Pandas DataFrame is two-dimensional tabular data structure with labeled axes (rows and columns)

# %%
#importing the pandas library
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a pandas DataFrame

# %%
#importing the california data set
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()

# %%
type(housing)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(fetch_california_housing)
# Out:
# <function fetch_california_housing at 0x7ac3e06e0b80>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#csv file to pandas df
diabetes_df=pd.read_csv('/content/diabetes.csv')

# %%
type(diabetes_df)
# Out:
# pandas.core.frame.DataFrame

# %%
#head() -->> print the first 5 columns
diabetes_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
diabetes_df.shape
# Out:
# (768, 9)

# %% [markdown]
# Loading the data from a excel file to pandas DataFrame:
#
# pd.read_excel('file path)

# %%
#exporting the pandas Dataframe to an excel file
#creating a DataFrame  with random values
random_df=pd.DataFrame(np.random.rand(20,10))

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.380061  0.616138  0.709623  0.803410  0.949417  0.120684  0.169202
# 1  0.648113  0.289153  0.129998  0.290346  0.354955  0.887053  0.478948
# 2  0.400364  0.873074  0.328065  0.289786  0.758320  0.504380  0.979716
# 3  0.615547  0.080437  0.478106  0.040425  0.110982  0.384327  0.994884
# 4  0.981816  0.046123  0.288774  0.076583  0.607876  0.242581  0.386838
#
#           7         8         9
# 0  0.556012  0.499763  0.536915
# 1  0.565208  0.046864  0.720183
# 2  0.150094  0.892472  0.530459
# 3  0.704658  0.913154  0.274026
# 4  0.629044  0.368838  0.567288

# %% [markdown]
# check the shape of above Dataframe

# %%
random_df.shape
# Out:
# (20, 10)

# %%
# export DataFrame to excel file
random_df.to_excel('')

# %%
# print the last 5 rows
random_df.tail()
# Out:
#            0         1         2         3         4         5         6  \
# 15  0.083628  0.017550  0.958275  0.328035  0.724092  0.668716  0.549713
# 16  0.539358  0.111353  0.729721  0.533913  0.948320  0.640143  0.248798
# 17  0.749707  0.201003  0.512507  0.644437  0.663401  0.430570  0.758063
# 18  0.607352  0.338711  0.914353  0.905119  0.563322  0.622506  0.739001
# 19  0.658814  0.490218  0.755205  0.038114  0.613492  0.145929  0.082699
#
#            7         8         9
# 15  0.855946  0.016421  0.738121
# 16  0.418948  0.918656  0.838569
# 17  0.612628  0.306438  0.508201
# 18  0.032217  0.054623  0.291982
# 19  0.751284  0.064220  0.686934

# %%
print(random_df)
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.380061  0.616138  0.709623  0.803410  0.949417  0.120684  0.169202
# 1   0.648113  0.289153  0.129998  0.290346  0.354955  0.887053  0.478948
# 2   0.400364  0.873074  0.328065  0.289786  0.758320  0.504380  0.979716
# 3   0.615547  0.080437  0.478106  0.040425  0.110982  0.384327  0.994884
# 4   0.981816  0.046123  0.288774  0.076583  0.607876  0.242581  0.386838
# 5   0.313685  0.281232  0.511905  0.425149  0.149107  0.823649  0.411155
# 6   0.274170  0.782270  0.754215  0.061093  0.580849  0.843808  0.505454
# 7   0.757066  0.868746  0.179482  0.302023  0.399499  0.853360  0.149925
# 8   0.471420  0.457510  0.998406  0.033665  0.656292  0.217843  0.031714
# 9   0.730935  0.941004  0.407492  0.558171  0.412853  0.439838  0.884870
# 10  0.557985  0.965302  0.314820  0.547315  0.026803  0.203998  0.953846
# 11  0.693196  0.648626  0.280417  0.136302  0.749381  0.434767  0.667974
# 12  0.251085  0.564044  0.132216  0.248758  0.110450  0.318987  0.898427
# 13  0.989753  0.148302  0.148357  0.340886  0.519717  0.809087  0.430348
# 14  0.042112  0.576822  0.855666  0.810945  0.532956  0.713803  0.126163
# 15  0.083628  0.017550  0.958275  0.328035  0.724092  0.668716  0.549713
# 16  0.539358  0.111353  0.729721  0.533913  0.948320  0.640143  0.248798
# 17  0.749707  0.201003  0.512507  0.644437  0.663401  0.430570  0.758063
# 18  0.607352  0.338711  0.914353  0.905119  0.563322  0.622506  0.739001
# 19  0.658814  0.490218  0.755205  0.038114  0.613492  0.145929  0.082699
#
#            7         8         9
# 0   0.556012  0.499763  0.536915
# 1   0.565208  0.046864  0.720183
# 2   0.150094  0.892472  0.530459
# 3   0.704658  0.913154  0.274026
# 4   0.629044  0.368838  0.567288
# 5   0.753259  0.976715  0.645812
# 6   0.131356  0.609368  0.404533
# 7   0.082606  0.182625  0.203133
# 8   0.836829  0.652871  0.272553
# 9   0.085785  0.233595  0.860305
# 10  0.242847  0.080003  0.667159
# 11  0.790040  0.316722  0.130245
# 12  0.429600  0.968144  0.636314
# 13  0.577185  0.260789  0.635795
# 14  0.489394  0.913757  0.116953
# 15  0.855946  0.016421  0.738121
# 16  0.418948  0.918656  0.838569
# 17  0.612628  0.306438  0.508201
# 18  0.032217  0.054623  0.291982
# 19  0.751284  0.064220  0.686934

# %%
random_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       20 non-null     float64
#  1   1       20 non-null     float64
#  2   2       20 non-null     float64
#  3   3       20 non-null     float64
#  4   4       20 non-null     float64
#  5   5       20 non-null     float64
#  6   6       20 non-null     float64
#  7   7       20 non-null     float64
#  8   8       20 non-null     float64
#  9   9       20 non-null     float64
# dtypes: float64(10)
# memory usage: 1.7 KB

# %%
#finding the number of missing values
diabetes_df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#count the specific value
diabetes_df.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
#group the values based on their mean
diabetes_df.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %% [markdown]
# Statistical measures

# %%
#count or number of values
diabetes_df.count()
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
#mean
diabetes_df.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
#standard deviation
diabetes_df.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
#minimum value
diabetes_df.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
#maximum value
diabetes_df.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
# all the statistical measures about the dataFrame
diabetes_df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# Manipulating a Data Frame
